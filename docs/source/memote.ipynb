# %% [markdown]
# # Using Git to track changes made to the model along with preparing of the project for the use of Memote

# %% [markdown]
# ## Using Git and Memote

# %% [markdown]
# In the following, the changes made to the model are documented using Git and evaluated using [Memote](https://memote.readthedocs.io/en/latest/) [Memote](https://memote.io/), a test suite for standardized genome-scale metabolic model testing [add Ref].

# %% [markdown]
# For this we first install Memote.
#
# > `$ pip install memote`

# %% [markdown]
# **For the next step we already need the selected model locally in SBML format. Therefore, the selected model should be downloaded at this point.**
#
# To be able to use Memote with all of its features a new repository needs to be created. This can be done using the following command.
# **(To use the online features of Memote, it is necessary to answer the questions regarding GitHub.)**
#
# > `$ memote new`
#
# This command requires questions to be answered interactively. Thus it is not possible to execute this command in this tutorial Jupyter Notebooks.
#
# When using Memote interactively, the model [and its location? - Can we shorten the sentence like this] can be named and when it is named ['specified' you mean?] and when it is named ['specified' you mean?], the location of the source model can be specified. Memote then creates a folder, after a few more questions, where configuration files for Memote and Git are automatically created and where the model is also stored.
#
# Here we use the default values for all questions.

# %% [markdown]
# Next, we change the working directory to the folder created by Memote.

# %%
directory = "/home/jan/arbeit/memote_test/memote-model-repository"
# %cd $directory

# %% [markdown]
# Memote automatically installs [GitPython](https://gitpython.readthedocs.io/en/stable/), which enables using the functionalities of Git. Additionally, we import the following functions which will be used later.

# %%
from git import Repo
from cobra.io import write_sbml_model, validate_sbml_model
from cobramod import add_reactions

# %% [markdown]
# In this folder, we can now work on the model with Memote and CobraMod. After the completed processing of the model, all changes can be saved via git using a commit.
#
# First, we import the model copied into the folder.

# %%
model, errors = validate_sbml_model("model.xml")
errors
# Out:
# {'SBML_FATAL': [],
#  'SBML_ERROR': [],
#  'SBML_SCHEMA_ERROR': [],
#  'SBML_WARNING': [],
#  'COBRA_FATAL': [],
#  'COBRA_ERROR': [],
#  'COBRA_WARNING': [],
#  'COBRA_CHECK': []}

# %% [markdown]
# At this point, we can make changes to the current model, save additional files, such as a summary using CobraMod, special reports using Memote, or files we have created yourselves in the folder.
#
# Once all changes that should be saved have been made, we can save the current model in the previously created folder under the name chosen during "memote new". This is done directly using COBRApy.

# %%
write_sbml_model(model,"model.xml")

# %% [markdown]
# Next, the changes to be saved are passed to git. Using 'add', it can be individually determined whether all new/changed files should be added to the repository or not.
# This can also be defined systematically via a ".gitignore" file.
# Finally, we can perform a commit with a short description of the changes to the model.[Active language is usually the better choice. Easier to read and shorter.]
# **Finally, we perform a commit to track the changes made to the model. Here we provide a short description to summarize the changes in the model.**

# %%
from git import Repo
repo = Repo(directory)
repo.git.add(update=True)
repo.index.commit("This is a brief description of the changes.")
# Out:
# <git.Commit "d3bfe23dc7e901ca1db17c049c4d631ec3cce9ab">

# %% [markdown]
# If we want to send the changes to a configured Git server, we can execute the following commands. The configuration takes place for example during "memote new".

# %%
origin = repo.remote(name='origin')
origin.push()

# %% [markdown]
# All Git-related commands have been done here using GitPython but can also be replaced by the corresponding command-line commands.

# %% [markdown]
# **At this point we have finished preparing the project for the use of Memote and therefore all the functions of Memote can finally be used.
# But the connection to GitHub must exist to use the functions that require GitHub.**
#
# **The easiest way to do this is to answer the questions regarding GitHub during "memote new". Alternatively, GitHub can be added as a remote at a later time. However, this will not be discussed here.**
#
# **As an example, we used "memote run" here and obtained so the results of Memote's test suit exclusively in the commando line.**

# %% [markdown]
# Now all Memote functionalities can be used. This means that all local commands of Memote are available as well as all the functionalities that require a github repository. (For these, however, the appropriate specifications must have been made during Memote new).
# In the following example "memote run" is executed. [Please add one sentence here describing what the command does and finish with closing statement so the user can realize that we are at the end of the tutorial, e.g. "After completing the Memote tests, the results are saved/summarized/printed .... {I do not know, are they saved or printed, add whatever is corrrect} and can be inspected by the user."]

# %%
# !memote run
# Out:
# Checking `git` installation.
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
# The current solver interface glpk doesn't support setting the optimality tolerance.
# ============================= test session starts ==============================
# platform linux -- Python 3.7.4, pytest-4.6.11, py-1.10.0, pluggy-0.13.1 -- /home/jan/miniconda3/envs/cobramod/bin/python3.7
# cachedir: .pytest_cache
# rootdir: /home/jan
# plugins: anyio-3.3.0
# collected 146 items / 1 skipped / 145 selected
#
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_presence PASSED [  0%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_presence PASSED [  1%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_presence FAILED [  2%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[pubchem.compound] FAILED [  2%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[kegg.compound] FAILED [  3%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[seed.compound] PASSED [  4%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchikey] FAILED [  4%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[inchi] FAILED [  5%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[chebi] PASSED [  6%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[hmdb] FAILED [  6%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[reactome] FAILED [  7%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[metanetx.chemical] PASSED [  8%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[bigg.metabolite] PASSED [  8%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_overview[biocyc] FAILED [  9%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[rhea] FAILED [ 10%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[kegg.reaction] FAILED [ 10%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[seed.reaction] FAILED [ 11%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[metanetx.reaction] FAILED [ 12%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[bigg.reaction] PASSED [ 13%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[reactome] FAILED [ 13%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[ec-code] FAILED [ 14%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[brenda] FAILED [ 15%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_overview[biocyc] FAILED [ 15%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[refseq] FAILED [ 16%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[uniprot] FAILED [ 17%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ecogene] FAILED [ 17%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[kegg.genes] FAILED [ 18%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigi] FAILED [ 19%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbigene] FAILED [ 19%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ncbiprotein] FAILED [ 20%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[ccds] FAILED [ 21%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[hprd] FAILED [ 21%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_overview[asap] FAILED [ 22%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[pubchem.compound] FAILED [ 23%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[kegg.compound] PASSED [ 23%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[seed.compound] PASSED [ 24%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[inchikey] FAILED [ 25%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[inchi] FAILED [ 26%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[chebi] PASSED [ 26%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[hmdb] PASSED [ 27%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[reactome] FAILED [ 28%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[metanetx.chemical] PASSED [ 28%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[bigg.metabolite] PASSED [ 29%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_annotation_wrong_ids[biocyc] PASSED [ 30%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[rhea] FAILED [ 30%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[kegg.reaction] PASSED [ 31%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[seed.reaction] FAILED [ 32%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[metanetx.reaction] PASSED [ 32%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[bigg.reaction] PASSED [ 33%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[reactome] FAILED [ 34%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[ec-code] PASSED [ 34%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[brenda] FAILED [ 35%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_annotation_wrong_ids[biocyc] PASSED [ 36%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[refseq] FAILED [ 36%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[uniprot] PASSED [ 37%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ecogene] PASSED [ 38%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[kegg.genes] FAILED [ 39%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigi] PASSED [ 39%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbigene] PASSED [ 40%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ncbiprotein] FAILED [ 41%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[ccds] FAILED [ 41%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[hprd] FAILED [ 42%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_gene_product_annotation_wrong_ids[asap] PASSED [ 43%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_metabolite_id_namespace_consistency PASSED [ 43%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py::test_reaction_id_namespace_consistency PASSED [ 44%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_model_id_presence PASSED [ 45%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_genes_presence PASSED [ 45%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_reactions_presence PASSED [ 46%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_metabolites_presence PASSED [ 47%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_metabolites_formula_presence PASSED [ 47%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_metabolites_charge_presence PASSED [ 48%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_gene_protein_reaction_rule_presence FAILED [ 49%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_ngam_presence PASSED [ 50%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_metabolic_coverage FAILED [ 50%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_compartments_presence PASSED [ 51%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_protein_complex_presence PASSED [ 52%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_pure_metabolic_reactions PASSED [ 52%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_constrained_pure_metabolic_reactions PASSED [ 53%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_transport_reactions PASSED [ 54%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_constrained_transport_reactions PASSED [ 54%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_transport_reaction_gpr_presence PASSED [ 55%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_reversible_oxygen_reactions PASSED [ 56%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_unique_metabolites PASSED [ 56%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_metabolites_in_compartments PASSED [ 57%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_partially_identical_annotations FAILED [ 58%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_duplicate_reactions PASSED [ 58%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_reactions_with_identical_genes FAILED [ 59%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py::test_find_medium_metabolites FAILED [ 60%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_presence PASSED [ 60%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_consistency[BIOMASS_Ecoli_core_w_GAM] FAILED [ 61%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_default_production[BIOMASS_Ecoli_core_w_GAM] PASSED [ 62%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_open_production[BIOMASS_Ecoli_core_w_GAM] PASSED [ 63%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_precursors_default_production[BIOMASS_Ecoli_core_w_GAM] FAILED [ 63%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_biomass_precursors_open_production[BIOMASS_Ecoli_core_w_GAM] FAILED [ 64%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_gam_in_biomass[BIOMASS_Ecoli_core_w_GAM] PASSED [ 65%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_fast_growth_default[BIOMASS_Ecoli_core_w_GAM] FAILED [ 65%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_direct_metabolites_in_biomass[BIOMASS_Ecoli_core_w_GAM] PASSED [ 66%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py::test_essential_precursors_not_in_biomass[BIOMASS_Ecoli_core_w_GAM] FAILED [ 67%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_stoichiometric_consistency PASSED [ 67%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_unconserved_metabolites PASSED [ 68%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_inconsistent_min_stoichiometry PASSED [ 69%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM3] SKIPPED [ 69%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM63] SKIPPED [ 70%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM51] SKIPPED [ 71%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM121] SKIPPED [ 71%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM423] SKIPPED [ 72%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM6] SKIPPED [ 73%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM10] SKIPPED [ 73%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM38] SKIPPED [ 74%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM208] SKIPPED [ 75%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM191] SKIPPED [ 76%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM223] SKIPPED [ 76%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM7517] SKIPPED [ 77%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM12233] SKIPPED [ 78%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM558] SKIPPED [ 78%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM21] SKIPPED [ 79%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_detect_energy_generating_cycles[MNXM89557] SKIPPED [ 80%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_reaction_charge_balance PASSED [ 80%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_reaction_mass_balance PASSED [ 81%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_blocked_reactions PASSED [ 82%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_stoichiometrically_balanced_cycles FAILED [ 82%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_orphans PASSED [ 83%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_deadends FAILED [ 84%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_disconnected PASSED [ 84%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_produced_with_open_bounds FAILED [ 85%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_metabolites_not_consumed_with_open_bounds FAILED [ 86%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py::test_find_reactions_unbounded_flux_default_condition PASSED [ 86%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_essentiality.py::test_gene_essentiality_from_data_qualitative[experiment0] SKIPPED [ 87%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_growth.py::test_growth_from_data_qualitative[experiment0] SKIPPED [ 88%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_matrix.py::test_absolute_extreme_coefficient_ratio PASSED [ 89%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_matrix.py::test_number_independent_conservation_relations PASSED [ 89%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_matrix.py::test_matrix_rank PASSED [ 90%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_matrix.py::test_degrees_of_freedom PASSED [ 91%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbml.py::test_sbml_level PASSED [ 91%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbml.py::test_fbc_presence PASSED [ 92%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_sbo_presence PASSED [ 93%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_reaction_sbo_presence FAILED [ 93%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_gene_sbo_presence PASSED [ 94%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_metabolic_reaction_specific_sbo_presence PASSED [ 95%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_transport_reaction_specific_sbo_presence PASSED [ 95%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_metabolite_specific_sbo_presence PASSED [ 96%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_gene_specific_sbo_presence PASSED [ 97%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_exchange_specific_sbo_presence FAILED [ 97%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_demand_specific_sbo_presence SKIPPED [ 98%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_sink_specific_sbo_presence SKIPPED [ 99%]
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py::test_biomass_specific_sbo_presence PASSED [100%]
#
# =================================== FAILURES ===================================
# ____________________ test_gene_product_annotation_presence _____________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:116: in test_gene_product_annotation_presence
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 1 genes (0.73%) lack any form of         annotation: s0001
# E   assert 1 == 0
# E     -1
# E     +0
# ____________ test_metabolite_annotation_overview[pubchem.compound] _____________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 72 metabolites (100.00%) lack annotation for
# E     pubchem.compound:         13dpg_c, 2pg_c, 3pg_c, 6pgc_c, 6pgl_c, ...
# E   assert 72 == 0
# E     -72
# E     +0
# ______________ test_metabolite_annotation_overview[kegg.compound] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 metabolites (1.39%) lack annotation for kegg.compound:
# E     q8h2_c
# E   assert 1 == 0
# E     -1
# E     +0
# ________________ test_metabolite_annotation_overview[inchikey] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 72 metabolites (100.00%) lack annotation for inchikey:
# E     13dpg_c, 2pg_c, 3pg_c, 6pgc_c, 6pgl_c, ...
# E   assert 72 == 0
# E     -72
# E     +0
# __________________ test_metabolite_annotation_overview[inchi] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 72 metabolites (100.00%) lack annotation for inchi:
# E     13dpg_c, 2pg_c, 3pg_c, 6pgc_c, 6pgl_c, ...
# E   assert 72 == 0
# E     -72
# E     +0
# __________________ test_metabolite_annotation_overview[hmdb] ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 8 metabolites (11.11%) lack annotation for hmdb:
# E     3pg_c, amp_c, atp_c, fdp_c, nad_c, ...
# E   assert 8 == 0
# E     -8
# E     +0
# ________________ test_metabolite_annotation_overview[reactome] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 72 metabolites (100.00%) lack annotation for reactome:
# E     13dpg_c, 2pg_c, 3pg_c, 6pgc_c, 6pgl_c, ...
# E   assert 72 == 0
# E     -72
# E     +0
# _________________ test_metabolite_annotation_overview[biocyc] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:169: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 2 metabolites (2.78%) lack annotation for biocyc:
# E     fdp_c, icit_c
# E   assert 2 == 0
# E     -2
# E     +0
# ___________________ test_reaction_annotation_overview[rhea] ____________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 40 reactions (42.11%) lack annotation for rhea:
# E     ACALDt, ACt2r, ATPS4r, BIOMASS_Ecoli_core_w_GAM, CO2t, ...
# E   assert 40 == 0
# E     -40
# E     +0
# _______________ test_reaction_annotation_overview[kegg.reaction] _______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 53 reactions (55.79%) lack annotation for kegg.reaction:
# E     ACALDt, ACt2r, AKGt2r, ATPS4r, BIOMASS_Ecoli_core_w_GAM, ...
# E   assert 53 == 0
# E     -53
# E     +0
# _______________ test_reaction_annotation_overview[seed.reaction] _______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 95 reactions (100.00%) lack annotation for
# E     seed.reaction:         ACALD, ACALDt, ACKr, ACONTa, ACONTb, ...
# E   assert 95 == 0
# E     -95
# E     +0
# _____________ test_reaction_annotation_overview[metanetx.reaction] _____________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 21 reactions (22.11%) lack annotation for
# E     metanetx.reaction:         BIOMASS_Ecoli_core_w_GAM, EX_ac_e,
# E     EX_acald_e, EX_akg_e, EX_co2_e, ...
# E   assert 21 == 0
# E     -21
# E     +0
# _________________ test_reaction_annotation_overview[reactome] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 95 reactions (100.00%) lack annotation for reactome:
# E     ACALD, ACALDt, ACKr, ACONTa, ACONTb, ...
# E   assert 95 == 0
# E     -95
# E     +0
# __________________ test_reaction_annotation_overview[ec-code] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 44 reactions (46.32%) lack annotation for ec-code:
# E     ACALDt, ACt2r, AKGt2r, BIOMASS_Ecoli_core_w_GAM, CO2t, ...
# E   assert 44 == 0
# E     -44
# E     +0
# __________________ test_reaction_annotation_overview[brenda] ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 95 reactions (100.00%) lack annotation for brenda:
# E     ACALD, ACALDt, ACKr, ACONTa, ACONTb, ...
# E   assert 95 == 0
# E     -95
# E     +0
# __________________ test_reaction_annotation_overview[biocyc] ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:222: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 43 reactions (45.26%) lack annotation for biocyc:
# E     ACALDt, ACONTb, BIOMASS_Ecoli_core_w_GAM, CYTBD, ETOHt2r, ...
# E   assert 43 == 0
# E     -43
# E     +0
# ________________ test_gene_product_annotation_overview[refseq] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 137 genes (100.00%) lack annotation for refseq:
# E     b0351, b1241, s0001, b2296, b3115, ...
# E   assert 137 == 0
# E     -137
# E     +0
# ________________ test_gene_product_annotation_overview[uniprot] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 genes (0.73%) lack annotation for uniprot:
# E     s0001
# E   assert 1 == 0
# E     -1
# E     +0
# ________________ test_gene_product_annotation_overview[ecogene] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 genes (0.73%) lack annotation for ecogene:
# E     s0001
# E   assert 1 == 0
# E     -1
# E     +0
# ______________ test_gene_product_annotation_overview[kegg.genes] _______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 137 genes (100.00%) lack annotation for kegg.genes:
# E     b0351, b1241, s0001, b2296, b3115, ...
# E   assert 137 == 0
# E     -137
# E     +0
# ________________ test_gene_product_annotation_overview[ncbigi] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 genes (0.73%) lack annotation for ncbigi:
# E     s0001
# E   assert 1 == 0
# E     -1
# E     +0
# _______________ test_gene_product_annotation_overview[ncbigene] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 genes (0.73%) lack annotation for ncbigene:
# E     s0001
# E   assert 1 == 0
# E     -1
# E     +0
# ______________ test_gene_product_annotation_overview[ncbiprotein] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 137 genes (100.00%) lack annotation for ncbiprotein:
# E     b0351, b1241, s0001, b2296, b3115, ...
# E   assert 137 == 0
# E     -137
# E     +0
# _________________ test_gene_product_annotation_overview[ccds] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 137 genes (100.00%) lack annotation for ccds:
# E     b0351, b1241, s0001, b2296, b3115, ...
# E   assert 137 == 0
# E     -137
# E     +0
# _________________ test_gene_product_annotation_overview[hprd] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 137 genes (100.00%) lack annotation for hprd:
# E     b0351, b1241, s0001, b2296, b3115, ...
# E   assert 137 == 0
# E     -137
# E     +0
# _________________ test_gene_product_annotation_overview[asap] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:275: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1 genes (0.73%) lack annotation for asap:         s0001
# E   assert 1 == 0
# E     -1
# E     +0
# ____________ test_metabolite_annotation_wrong_ids[pubchem.compound] ____________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:320: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the pubchem.compound database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________ test_metabolite_annotation_wrong_ids[inchikey] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:320: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the inchikey database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_metabolite_annotation_wrong_ids[inchi] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:320: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the inchi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________ test_metabolite_annotation_wrong_ids[reactome] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:320: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the reactome database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________ test_reaction_annotation_wrong_ids[rhea] ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:393: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 1 reaction annotations (1.05%) do not match the
# E     regular expression patterns defined on identifiers.org for the rhea
# E     database: GLNabc
# E   assert 1 == 0
# E     -1
# E     +0
# ______________ test_reaction_annotation_wrong_ids[seed.reaction] _______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:379: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the seed.reaction database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_reaction_annotation_wrong_ids[reactome] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:379: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the reactome database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________ test_reaction_annotation_wrong_ids[brenda] __________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:379: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the brenda database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________ test_gene_product_annotation_wrong_ids[refseq] ________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:438: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the refseq database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ______________ test_gene_product_annotation_wrong_ids[kegg.genes] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:438: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the kegg.genes database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _____________ test_gene_product_annotation_wrong_ids[ncbiprotein] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:438: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbiprotein database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_gene_product_annotation_wrong_ids[ccds] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:438: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ccds database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_gene_product_annotation_wrong_ids[hprd] _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_annotation.py:438: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the hprd database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________ test_gene_protein_reaction_rule_presence ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py:209: in test_gene_protein_reaction_rule_presence
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are a total of 6 reactions (6.32%) without GPR:         ETOHt2r,
# E     ATPM, PYRt2, ACt2r, BIOMASS_Ecoli_core_w_GAM, ...
# E   assert 6 == 0
# E     -6
# E     +0
# ___________________________ test_metabolic_coverage ____________________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py:273: in test_metabolic_coverage
#     assert ann["metric"] >= 1, ann["message"]
# E   AssertionError: The degree of metabolic coverage is 0.69.
# E   assert 0.6934306569343066 >= 1
# ___________ test_find_reactions_with_partially_identical_annotations ___________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py:641: in test_find_reactions_with_partially_identical_annotations
#     assert total == 0, ann["message"]
# E   AssertionError: Based on annotations there are 1 different groups of overlapping
# E     annotation which corresponds to a total of 2 duplicated reactions in
# E     the model.
# E   assert 2 == 0
# E     -2
# E     +0
# ___________________ test_find_reactions_with_identical_genes ___________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py:714: in test_find_reactions_with_identical_genes
#     assert num_dup == 0, ann["message"]
# E   AssertionError: Based only on equal genes there are 5 different groups of
# E     identical reactions which corresponds to a total of 12
# E     duplicated reactions in the model.
# E   assert 12 == 0
# E     -12
# E     +0
# _________________________ test_find_medium_metabolites _________________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_basic.py:735: in test_find_medium_metabolites
#     ann["metric"] = len(ann["data"]) / num_ex
# E   TypeError: unsupported operand type(s) for /: 'int' and 'list'
# ----------------------------- Captured stderr call -----------------------------
# Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# ------------------------------ Captured log call -------------------------------
# INFO     cobra.medium.boundary_types:boundary_types.py:67 Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# INFO     cobra.medium.boundary_types:boundary_types.py:67 Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# ______________ test_biomass_consistency[BIOMASS_Ecoli_core_w_GAM] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py:129: in test_biomass_consistency
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: The component molar mass of the biomass reaction
# E     BIOMASS_Ecoli_core_w_GAM sums up to 1.5407661664547085
# E     which is outside of the 1e-03 margin from 1 mmol / g[CDW] / h.
# E   assert False
# _____ test_biomass_precursors_default_production[BIOMASS_Ecoli_core_w_GAM] _____
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py:250: in test_biomass_precursors_default_production
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction BIOMASS_Ecoli_core_w_GAM and when the model
# E     is simulated on the         provided default medium a total of 3
# E     precursors         (21.43% of all precursors except h2o and atp)
# E     cannot be produced: ['nad_c', 'accoa_c', 'nadph_c']
# E   assert 3 == 0
# E     -3
# E     +0
# ______ test_biomass_precursors_open_production[BIOMASS_Ecoli_core_w_GAM] _______
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py:301: in test_biomass_precursors_open_production
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction BIOMASS_Ecoli_core_w_GAM and when the model
# E     is simulated in         complete medium a total of 3 precursors
# E     (21.43% of all precursors except h2o and atp) cannot be produced:
# E     ['nad_c', 'accoa_c', 'nadph_c']
# E   assert 3 == 0
# E     -3
# E     +0
# ______________ test_fast_growth_default[BIOMASS_Ecoli_core_w_GAM] ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py:433: in test_fast_growth_default
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction BIOMASS_Ecoli_core_w_GAM and when the model
# E     is simulated on             the provided default medium the growth
# E     rate is *lower* than that             of the fastest bacteria. This is
# E     to be expected for             a majority of organisms.
# E   assert False
# ______ test_essential_precursors_not_in_biomass[BIOMASS_Ecoli_core_w_GAM] ______
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_biomass.py:573: in test_essential_precursors_not_in_biomass
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: BIOMASS_Ecoli_core_w_GAM lacks a total of 30 essential metabolites
# E     (214.29% of all biomass precursors). Specifically         these are:
# E     ['MNXM94', 'MNXM55', 'MNXM134', 'MNXM76', 'MNXM61', 'MNXM97',
# E     'MNXM53', 'MNXM114', 'MNXM42', 'MNXM142', 'MNXM231', 'MNXM70',
# E     'MNXM78', 'MNXM199', 'MNXM140', 'MNXM32', 'MNXM29', 'MNXM147',
# E     'MNXM286', 'MNXM360', 'MNXM394', 'MNXM344', 'MNXM51', 'MNXM63',
# E     'MNXM121', 'MNXM16', 'MNXM33', 'MNXM161', 'MNXM256', 'MNXM119'].
# E   assert 30 == 0
# E     -30
# E     +0
# _________________ test_find_stoichiometrically_balanced_cycles _________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py:299: in test_find_stoichiometrically_balanced_cycles
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 2 (2.11%) reactions         which participate in SBC in the
# E     model: FRD7, SUCDi
# E   assert 2 == 0
# E     -2
# E     +0
# ______________________________ test_find_deadends ______________________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py:352: in test_find_deadends
#     assert ann["data"] == 0, ann["message"]
# E   AssertionError: A total of 0 (0.00%) metabolites are not consumed by any reaction
# E     of the model:
# E   assert [] == 0
# E     -[]
# E     +0
# ----------------------------- Captured stderr call -----------------------------
# Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# ------------------------------ Captured log call -------------------------------
# INFO     cobra.medium.boundary_types:boundary_types.py:67 Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# _____________ test_find_metabolites_not_produced_with_open_bounds ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py:408: in test_find_metabolites_not_produced_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 12 (16.67%) metabolites cannot be produced in complete
# E     medium: accoa_c, adp_c, amp_c, atp_c, coa_c, ...
# E   assert 12 == 0
# E     -12
# E     +0
# ----------------------------- Captured stderr call -----------------------------
# Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# ------------------------------ Captured log call -------------------------------
# INFO     cobra.medium.boundary_types:boundary_types.py:67 Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# _____________ test_find_metabolites_not_consumed_with_open_bounds ______________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_consistency.py:438: in test_find_metabolites_not_consumed_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 12 (16.67%) metabolites cannot be consumed in complete
# E     medium: accoa_c, adp_c, amp_c, atp_c, coa_c, ...
# E   assert 12 == 0
# E     -12
# E     +0
# ----------------------------- Captured stderr call -----------------------------
# Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# ------------------------------ Captured log call -------------------------------
# INFO     cobra.medium.boundary_types:boundary_types.py:67 Compartment `e` sounds like an external compartment. Using this one without counting boundary reactions.
# __________________________ test_reaction_sbo_presence __________________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py:89: in test_reaction_sbo_presence
#     assert len(ann["data"]) == len(model.reactions), ann["message"]
# E   AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 95
# E     -0
# E     +95
# _____________________ test_exchange_specific_sbo_presence ______________________
# ../../../miniconda3/envs/cobramod/lib/python3.7/site-packages/memote/suite/tests/test_sbo.py:309: in test_exchange_specific_sbo_presence
#     assert len(ann["data"]) == len(exchanges), ann["message"]
# E   AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# E     reactions) lack annotation with the SBO term "SBO:0000627" for
# E     'exchange reaction':
# E   assert 0 == 20
# E     -0
# E     +20
# =============== 55 failed, 71 passed, 21 skipped in 2.77 seconds ===============
# Checking out deployment branch.
# Committing result and changing back to working branch.
# Storing result in 'results/d3bfe23dc7e901ca1db17c049c4d631ec3cce9ab.json.gz'.
